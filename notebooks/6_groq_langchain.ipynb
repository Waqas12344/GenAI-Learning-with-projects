# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_google_genai import ChatGoogleGenerativeAI
googlellm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
res = llm.invoke("What is GenAI?")

# %%
googleres = googlellm.invoke("What is GenAI?")

# %%
res.content
# Out:
# '**GenAI** (short for *generative artificial intelligence*) is a class of AI systems that can create new content—such as text, images, audio, video, code, or even 3‑D models—rather than just analyzing or classifying existing data.\n\n| Aspect | What it means for GenAI |\n|--------|--------------------------|\n| **Core capability** | *Generation*: producing original outputs that didn’t exist before, based on patterns learned from large datasets. |\n| **Typical outputs** | • Natural‑language text (stories, essays, chat replies)  <br>• Images or artwork (photos, illustrations)  <br>• Audio/music  <br>• Code snippets  <br>• Video clips, 3‑D assets, synthetic data |\n| **Key technologies** | • **Transformer architectures** (e.g., GPT, BERT, T5) for language  <br>• **Diffusion models** (e.g., Stable Diffusion, DALL‑E 3) for images  <br>• **Variational Autoencoders (VAEs)**, **GANs** (Generative Adversarial Networks) for many modalities  <br>• **Multimodal models** that handle text\u202f+\u202fimage\u202f+\u202faudio together (e.g., GPT‑4V, Flamingo, Gemini). |\n| **Training data** | Massive, diverse datasets—billions of words, millions of images, hours of audio—so the model learns statistical regularities and can extrapolate new combinations. |\n| **How it works (high‑level)** | 1. **Pre‑training**: The model ingests huge corpora and learns to predict the next token (word, pixel patch, audio frame, etc.).  <br>2. **Fine‑tuning / instruction tuning**: It is further trained on more specific tasks or with human feedback to follow prompts reliably.  <br>3. **Inference**: When given a prompt, the model samples from its learned probability distribution to generate the next piece of content, iterating until the output is complete. |\n| **Common use cases** | • Conversational assistants (ChatGPT, Claude)  <br>• Content creation (blog posts, marketing copy, scripts)  <br>• Design & art (image generation, logo design)  <br>• Code assistance (Copilot, Code Llama)  <br>• Data augmentation for ML (synthetic images, text)  <br>• Education & tutoring  <br>• Prototyping product mock‑ups, game assets, etc. |\n| **Differences from “traditional” AI** | Traditional AI (e.g., rule‑based systems, classic classifiers) *recognizes* patterns or makes decisions based on pre‑defined logic. GenAI *creates* new artifacts, often with a degree of creativity and variability that mimics human imagination. |\n| **Limitations & risks** | • **Hallucinations**: producing plausible‑looking but factually wrong information.  <br>• **Bias**: reflecting stereotypes present in training data.  <br>• **Intellectual‑property concerns**: generated content may inadvertently copy copyrighted material.  <br>• **Misuse**: deepfakes, disinformation, spam.  <br>• **Resource intensity**: training large models consumes substantial compute and energy. |\n| **Current landscape (2024‑2025)** | • **Open‑source**: LLaMA‑2, Mistral, Stable Diffusion, Flux.  <br>• **Commercial**: OpenAI’s GPT‑4/4o, Anthropic’s Claude, Google Gemini, Microsoft Copilot, Adobe Firefly.  <br>• **Multimodal push**: models that can take text+image+audio prompts and output any of those modalities.  <br>• **Regulation**: emerging policies around labeling, watermarking, and responsible deployment. |\n\n### TL;DR\nGenAI = AI that *generates* new, human‑like content across many media types using large, transformer‑based (or diffusion/GAN) models trained on massive datasets. It powers chatbots, image generators, code assistants, and a growing suite of creative and productivity tools, while also raising important ethical and technical challenges.'

# %%
googleres.content[0]
# Out:
# {'type': 'text',
#  'text': '**Generative AI (GenAI)** is a type of artificial intelligence that can **create new content**—including text, images, audio, video, and computer code—rather than just analyzing or classifying existing data.\n\nWhile traditional AI (often called "discriminative" or "predictive" AI) focuses on recognizing patterns to make decisions or predictions (like suggesting a movie on Netflix or flagging spam emails), GenAI uses complex machine learning models to generate original outputs that feel human-made.\n\nHere is a breakdown of how it works and what it does.\n\n---\n\n### 1. How does it work?\nGenAI is powered by **Foundation Models**—massive AI models trained on vast amounts of data (such as books, articles, websites, and images). \n\nThe most common architecture behind these models is the **Transformer**, which allows the AI to understand the relationships between different pieces of data. For example, in a text model, the AI calculates the statistical probability of which word should come next in a sequence based on the context of the words that came before it.\n\n### 2. Common Types of GenAI\n*   **Text-to-Text (Large Language Models):** These can write essays, summarize documents, draft emails, or engage in conversation. \n    *   *Examples:* ChatGPT (OpenAI), Claude (Anthropic), Gemini (Google).\n*   **Text-to-Image:** These convert descriptive prompts into visual art or photorealistic images.\n    *   *Examples:* Midjourney, DALL-E 3, Stable Diffusion.\n*   **Text-to-Video/Audio:** These create short video clips or synthesize realistic human voices or music from text prompts.\n    *   *Examples:* Sora (OpenAI), Suno (music), ElevenLabs (voice cloning).\n*   **Code Generation:** These assist developers by writing, debugging, or translating programming languages.\n    *   *Examples:* GitHub Copilot, Cursor.\n\n### 3. Why is it a "Big Deal"?\nGenAI is considered a "general-purpose technology" because it has the potential to transform almost every industry:\n*   **Productivity:** It automates repetitive tasks like drafting reports or analyzing long legal documents.\n*   **Creativity:** It acts as a "co-pilot," allowing people to prototype ideas or generate visuals instantly.\n*   **Personalization:** It can tailor educational materials to a specific student\'s learning style or create customized marketing copy at scale.\n\n### 4. Key Limitations and Risks\nDespite its power, GenAI comes with significant challenges:\n*   **Hallucinations:** GenAI models can confidently state incorrect information as if it were fact because they are "guessing" based on probabilities, not checking against a verified database.\n*   **Bias:** Because models are trained on internet data, they can inherit and amplify human prejudices and stereotypes found in that data.\n*   **Copyright and Ethics:** There is ongoing debate about the legality of training models on copyrighted work and the potential for "deepfakes" to spread misinformation.\n*   **Security:** There are concerns regarding data privacy—if you input sensitive corporate or personal data into a public chatbot, that data could potentially be used to train future versions of the model.\n\n### Summary\nIf traditional AI is the **"analyst"** (reading the room to tell you what\'s happening), GenAI is the **"artist/writer"** (using what it knows to build something entirely new). It represents a shift from machines simply *processing* information to machines *producing* it.',
#  'extras': {'signature': 'EnEKbwERTTIP7BMiIbLIY2lb2PPSag/MGI0i8/6MxW1TaMYSmcoK+iyCYDzQZLM1Q6zvzZi7H0DuH3hbvbe0C76t163N47Ag/B6heyAjy3JB9SjbrFnOh82xqF5/y5xdpsrJ+PqnwJuzw3I2TOFtOzAEAg=='}}
