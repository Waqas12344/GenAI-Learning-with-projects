# %% [markdown]
# ### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
res = llm.invoke("Who is pm of pakistan?")
res.content
# Out:
# [{'type': 'text',
#   'text': 'The current Prime Minister of Pakistan is **Shehbaz Sharif**. He took office on March 4, 2024.',
#   'extras': {'signature': 'EnEKbwERTTIP+jYBdXeDpJv3CRZyFRPgQfYdwas7LKq2P6sNikkXP9IWKXkMUErki7aoFBTQfmo0j/3HdlMk7wY3lWDrDPhvIz8kMCdGyl4g0lEzgC3D1XqPkf+0WjZa9/QdB8kbzZ3+6WgQVKMAsaitHw=='}}]

# %% [markdown]
# ## Static Prompt

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
prompts = [
    ("system", "You are a javascript developer"),
    ("user", "Write a code to display hello world"),
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# [{'type': 'text', 'text': 'In JavaScript, there are a few ways to display "Hello World" depending on where you are running the code.\n\n### 1. In the Browser Console (Most common for debugging)\nIf you are working in a browser (Chrome, Firefox, etc.), you can press `F12` to open the developer tools and type this:\n\n```javascript\nconsole.log("Hello World");\n```\n\n### 2. In a Web Page (Visible to the user)\nIf you want to display the text directly on the webpage, you can use `document.write`:\n\n```javascript\ndocument.write("Hello World");\n```\n\n### 3. As an Alert Box\nIf you want a pop-up window to appear on the screen:\n\n```javascript\nalert("Hello World");\n```\n\n### 4. In a Node.js Environment (Terminal)\nIf you have [Node.js](https://nodejs.org/) installed and you are running a script from your terminal/command prompt, save your code in a file (e.g., `app.js`) and run `node app.js`:\n\n```javascript\nconsole.log("Hello World");\n```\n\n---\n\n**Pro Tip:** If you want to see how to include this in a proper HTML file, here is the standard structure:\n\n```html\n<!DOCTYPE html>\n<html>\n<body>\n    <script>\n        console.log("Hello World");\n    </script>\n</body>\n</html>\n```', 'extras': {'signature': 'EnEKbwERTTIPEleWcN/KSf055pZOK1dR5s0mypDumeqtw6t4+GDb0IrPCgCSyNR2HtH3LATO41BNzDH1B8khs+/UkKe6Qp2SK+PyQ6zeN3mAfbbCVIJ05EuFcN67rPo7qnKlPqfrE2pBXvPtLEDe07QCmQ=='}}]
